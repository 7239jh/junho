# %%
import pandas as pd
df=pd.read_excel('D:/정리/newsdata.xlsx')
df
# Out:
#                                   title section  \
# 0         태영호 "김정은에 필요한 건 자금…비핵화 의사 없다"      세계
# 1        므누신 美재무, 미중 무역협상 마친 뒤 "생산적 회의"      세계
# 2    '러시아 미사일 美 본토 겨냥' 푸틴 발언 두고 러-서방 공방      세계
# 3              "中·러, 작년 北 노동자 절반 이상 송환"      세계
# 4                  이것이 2차 북미정상회담 '기념우표'      세계
# ..                                  ...     ...
# 995             경차 전문기업 동희오토…'에너지도 챔피언'      경제
# 996                     카카오, 특별관계자 지분변동      경제
# 997               현대렌탈케어, 매트리스 렌털 상품 출시      경제
# 998               한일화학, 주당 150원 현금배당 결정      경제
# 999     깨끗한나라, 김민환·최현수 CEO 내정…2세 경영 본격화      경제
#
#                                                   text
# 0    NHK 인터뷰 "트럼프에 개성공단·금강산 관광 재개 요구할 것"태영호 전 영국주재 ...
# 1    므누신 미 재무장관 "생산적 회의였다"[스티븐 므누신 미국 재무장관 트위터 캡처](...
# 2    나토 "동맹국 겨냥 발언 용납 못해"…러 "전적으로 방어적 조치"러 전문가 "신형 ...
# 3    러시아가 지난해 자국에서 일하는 북한 노동자 약 3만 명 가운데 거의 3분의 2를 ...
# 4    (하노이=뉴스1) 이원준 기자 = 베트남 정부가 26일(현지시간) 공개한 2차 북미...
# ...

# %% [markdown]
# #### 행 셔플

# %%
dfs=df.sample(frac=1)
dfs
# Out:
#                                    title section  \
# 35                브라질 리우 일대 폭우로 최소 6명 숨져      세계
# 508          국무회의, 예비타당성조사 면제사업 선정 결과 의결      사회
# 922                AfDB 총재와 면담하는 홍남기 부총리      경제
# 269                       어수선한 자유한국당 회의장      정치
# 187             북·미 종전선언은 남북 별도 국가 인정 의미      세계
# ..                                   ...     ...
# 339            美와 전쟁-종전-수교…베트남, 北 미래 될까?      정치
# 496        與 "사법 적폐 보복 재판"…野 "대통령이 해명하라"      정치
# 64            5개 핵보유국 "핵확산 방지 이슈 해결에 최선"      세계
# 608                        계속 하락하는 양파 가격      사회
# 712  점심시간 쪼개, 교복입고…김복동 할머니 빈소에 시민 발길 이어져      사회
#
#                                                   text
# 35   브라질 남동부 리우데자네이루 시 일대에서 강풍을 동반한 폭우로 인명 피해가 속출하고...
# 508  【서울=뉴시스】박주성 기자 = 이낙연 국무총리가 29일 오전 서울 세종로 정부서울청...
# 922  【서울=뉴시스】홍남기 부총리 겸 기획재정부 장관이 8일 서울 광화문 정부서울청사에서...
# 269  (서울=연합뉴스) 이진욱 기자 = 12일 국회에서 자유한국당 원내대책회의가 열리고 ...
# 187  분계선이 국경선 돼…평화통일까지는 험난한 여정지난해 6월 싱가포르에서 만난 도널드 ...
# ...

# %% [markdown]
# #### 행 셔플(인덱스초기화)

# %%
dfss=df.sample(frac=1).reset_index(drop=True)
dfss
# Out:
#                                         title section  \
# 0    [일문일답] 손학규 “보수만으론 정치 못한다…유승민, 진보 받아들일 것”      정치
# 1         창원성산 보선에 사활 건 정의당…이정미 "창원에 집 얻어 상주"      정치
# 2               네이버 노조 '쟁의행위' 가결…설 이후 단체행동 돌입      사회
# 3                     인천 여객선 이용객 4~5일 가장 많을 듯      사회
# 4              국회 외통위원들께 김연철의 '70년의 대화'를 권합니다      세계
# ..                                        ...     ...
# 995                         회담장 미리 찾은 북측 경호원들      세계
# 996        "겨울철 손가락 푸른색→붉은색 변하면 '레이노 증후군' 의심"      사회
# 997     美사우스웨스트항공, 캘리포니아-하와이 취항…편도 49달러 '초저가'      세계
# 998                '불티나게 팔리던 티셔츠가 이제는 재고로 전락'      세계
# 999              엘오티베큠, 중국 업체와 30억 규모 공급계약 체결      경제
#
#                                                   text
# 0    -손 대표, 바른미래 창당 1주년 기자회견 12일 오전 국회에서 열린 바른미래당 창...
# 1    여영국 후보 "노 전 의원과 함께한 경험으로 창원경제 다시 뛰게 하겠다"여영국 후보...
# 2    사진=연합뉴스네이버 노동조합의 쟁의행위 찬반투표가 가결됐다.네이버 노조(민주노총 화...
# 3    이번 설 연휴에 인천과 섬 지역을 연결하는 연안여객선 이용객이 다음달 4일과 5일 ...
# ...
